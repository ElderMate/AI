# %%
import pandas as pd
import json

# %% [markdown]
# ## 납부 예정

# %%
# 파일 경로
file_path = './data/키워드추출/납부예정키워드.xlsx'

# 파일 내용 읽기
data = pd.read_excel(file_path)

# 데이터의 첫 5행을 출력해 데이터의 구조를 확인
data.head()
# Out:
#                                              message
# 0  [Web발신] SWING 언락패스 이용권(12,900원)이 1일 후 KB국민카드70...
# 1  [Web발신] SWING 언락패스 이용권(12,900원)이 1일 후 KB국민카드70...
# 2  [Web발신]\n[KB국민카드]장우진님 09/14 결제금액 599,554원(연회비 ...
# 3  [Web발신]\n[KB국민카드]장우진님 10/16 카드대금 642,364원(09/2...
# 4  [Web발신]\n[KB국민카드]장우진님 11/14 카드대금 696,667원(11/0...

# %%
new_data1 = [
{
"PAYEE":"SWING",
"COST":"12,900원",
"TIME":"1일 후",
"Payment Reason":"언락패스 이용권"
},
{
"PAYEE":"SWING",
"COST":"12,900원",
"TIME":"1일 후",
"Payment Reason":"언락패스 이용권"
},
{
"PAYEE":"KB국민카드",
"COST":"599,554원",
"TIME":"09/14",
"Payment Reason":"_"
},
{
"PAYEE":"KB국민카드",
"COST":"642,364원",
"TIME":"10/16",
"Payment Reason":"카드대금"
},
{
"PAYEE":"KB국민카드",
"COST":"696,667원",
"TIME":"11/14",
"Payment Reason":"카드대금"
},
{
"PAYEE":"KB국민카드",
"COST":"20,000원",
"TIME":"09/13",
"Payment Reason":"_"
},
{
"PAYEE":"KB국민카드",
"COST":"1,238원",
"TIME":"08/14",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"561,229원",
"TIME":"08/14",
"Payment Reason":"카드대금"
},
{
"PAYEE":"현대카드",
"COST":"5000원",
"TIME":"08/01",
"Payment Reason":"연회비"
},
{
"PAYEE":"현대카드",
"COST":"319,570원",
"TIME":"08/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"451,655원",
"TIME":"09/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"432,741원",
"TIME":"10/04",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"398,543원",
"TIME":"11/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"326,652원",
"TIME":"12/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"261,814원",
"TIME":"01/02",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"209,642원",
"TIME":"02/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"163,248원",
"TIME":"03/02",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"117,563원",
"TIME":"04/03",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"71,450원",
"TIME":"05/02",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"28,114원",
"TIME":"06/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"439,291원",
"TIME":"07/03",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"364,089원",
"TIME":"08/01",
"Payment Reason":"_"
},
{
"PAYEE":"현대카드",
"COST":"287,451원",
"TIME":"09/01",
"Payment Reason":"_"
},
{
"PAYEE":"KB국민카드",
"COST":"61,900원",
"TIME":"07/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"46,100원",
"TIME":"08/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"57,740원",
"TIME":"09/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"50,200원",
"TIME":"10/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"49,500원",
"TIME":"11/29",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"62,200원",
"TIME":"12/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"53,700원",
"TIME":"01/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"50,100원",
"TIME":"02/28",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"51,600원",
"TIME":"03/28",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"65,700원",
"TIME":"04/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"50,400원",
"TIME":"05/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"58,850원",
"TIME":"06/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"45,950원",
"TIME":"07/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"4,800원",
"TIME":"02/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"KB국민카드",
"COST":"9,700원",
"TIME":"03/27",
"Payment Reason":"후불교통"
},
{
"PAYEE":"삼성생명",
"COST":"37,939원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"75,322원",
"TIME":"26일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"111,652원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"139,819원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"176,435원",
"TIME":"26일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"214,507원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"46,687원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"87,068원",
"TIME":"26일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"126,321원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"삼성생명",
"COST":"167,048원",
"TIME":"25일",
"Payment Reason":"약대이자 미납"
},
{
"PAYEE":"신한체크",
"COST":"10,100원",
"TIME":"당일",
"Payment Reason":"후불교통이용대금"
}
]

# %%
data['result'] = pd.Series([str(result) for result in new_data1])

data.head()
# Out:
#                                              message  \
# 0  [Web발신] SWING 언락패스 이용권(12,900원)이 1일 후 KB국민카드70...
# 1  [Web발신] SWING 언락패스 이용권(12,900원)이 1일 후 KB국민카드70...
# 2  [Web발신]\n[KB국민카드]장우진님 09/14 결제금액 599,554원(연회비 ...
# 3  [Web발신]\n[KB국민카드]장우진님 10/16 카드대금 642,364원(09/2...
# 4  [Web발신]\n[KB국민카드]장우진님 11/14 카드대금 696,667원(11/0...
#
#                                               result
# 0  {'PAYEE': 'SWING', 'COST': '12,900원', 'TIME': ...
# 1  {'PAYEE': 'SWING', 'COST': '12,900원', 'TIME': ...
# 2  {'PAYEE': 'KB국민카드', 'COST': '599,554원', 'TIME'...
# 3  {'PAYEE': 'KB국민카드', 'COST': '642,364원', 'TIME'...
# 4  {'PAYEE': 'KB국민카드', 'COST': '696,667원', 'TIME'...

# %%
data.to_excel('./data/NER학습데이터/NER_납부예정.xlsx', index=False)

# %%
def find_substring_indices(message, result):
    annotations = []
    for key, value in result.items():
        start_index = message.find(value)
        if start_index != -1:  # Found the substring
            end_index = start_index + len(value)
            annotations.append((start_index, end_index, key.upper()))
    return annotations

# %%
# Convert the 'result' column back to dictionary format from string representation
data['result'] = data['result'].apply(lambda x: json.loads(x.replace("'", "\"")))

# Apply the function to find annotations for each row
data['annotations'] = data.apply(lambda row: find_substring_indices(row['message'], row['result']), axis=1)

# Show the DataFrame to confirm the 'annotations' column
data[['message', 'result', 'annotations']].head()
# Out:
#                                              message  \
# 0  [Web발신] SWING 언락패스 이용권(12,900원)이 1일 후 KB국민카드70...
# 1  [Web발신] SWING 언락패스 이용권(12,900원)이 1일 후 KB국민카드70...
# 2  [Web발신]\n[KB국민카드]장우진님 09/14 결제금액 599,554원(연회비 ...
# 3  [Web발신]\n[KB국민카드]장우진님 10/16 카드대금 642,364원(09/2...
# 4  [Web발신]\n[KB국민카드]장우진님 11/14 카드대금 696,667원(11/0...
#
#                                               result  \
# 0  {'PAYEE': 'SWING', 'COST': '12,900원', 'TIME': ...
# 1  {'PAYEE': 'SWING', 'COST': '12,900원', 'TIME': ...
# 2  {'PAYEE': 'KB국민카드', 'COST': '599,554원', 'TIME'...
# 3  {'PAYEE': 'KB국민카드', 'COST': '642,364원', 'TIME'...
# 4  {'PAYEE': 'KB국민카드', 'COST': '696,667원', 'TIME'...
#
#                                          annotations
# 0  [(8, 13, PAYEE), (23, 30, COST), (33, 37, TIME...
# 1  [(8, 13, PAYEE), (23, 30, COST), (33, 37, TIME...
# 2   [(9, 15, PAYEE), (32, 40, COST), (21, 26, TIME)]
# 3  [(9, 15, PAYEE), (32, 40, COST), (21, 26, TIME...
# 4  [(9, 15, PAYEE), (32, 40, COST), (21, 26, TIME...

# %%
data.to_excel('./data/NER학습데이터/NER_납부예정.xlsx', index=False)
